# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import partial
import cv2
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
import matplotlib.image as mpimg
from tensorflow.keras.optimizers import SGD
from keras.optimizers import adam
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os, shutil
from keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D 
from tensorflow.keras.layers import ZeroPadding2D, BatchNormalization, Convolution2D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import random
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, recall_score
from sklearn.metrics import f1_score, precision_score

# %%
early_stop = EarlyStopping(patience=2,monitor='loss')

# %%
tf.version.VERSION
# Out:
# '2.3.1'

# %%
train = os.path.join('/Users/AMINO/Desktop/Mod_4_Project/chest_xray/chest_xray/train')
test = os.path.join('/Users/AMINO/Desktop/Mod_4_Project/chest_xray/chest_xray/test')
validation = os.path.join('/Users/AMINO/Desktop/Mod_4_Project/chest_xray/chest_xray/val')

# %%
IMG_SIZE = (150, 150)

train_dataset = image_dataset_from_directory(train, image_size=IMG_SIZE)
test_dataset = image_dataset_from_directory(test, image_size=IMG_SIZE)
validation_dataset = image_dataset_from_directory(validation,image_size=IMG_SIZE)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.

# %% [markdown]
# 😀 Command Control Space

# %%
f = plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.bar(x=["pneumonia","normal"], height = (len(os.listdir(train + "/PNEUMONIA")),len(os.listdir(train + "/NORMAL"))))
plt.title("Training data set")
plt.subplot(1,3,2)
plt.bar(x=["pneumonia","normal"], height = (len(os.listdir(test + "/PNEUMONIA")),len(os.listdir(test + "/NORMAL"))))
plt.title("Test data set")
plt.subplot(1,3,3)
plt.bar(x=["pneumonia","normal"], height = (len(os.listdir(validation + "/PNEUMONIA")),len(os.listdir(validation + "/NORMAL"))))
plt.title("Validation data set")
# Out:
# Text(0.5, 1.0, 'Validation data set')

# %%
labels = ['NORMAL', 'PNEUMONIA']

# %%
SHAPE_OF_IMAGES = (150,150)

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis

# %%
def view_images(directory,n_of_images):
    plt.figure(figsize=(25,10))
    for i in range(0,n_of_images,2):
        random_label_p = random.choice(range(len(os.listdir(directory + "/PNEUMONIA"))))
        random_label_n = random.choice(range(len(os.listdir(directory + "/NORMAL"))))
        plt.subplot(2,n_of_images // 2, i+1)
        plt.imshow(cv2.imread(os.path.join(directory + "/PNEUMONIA/",os.listdir(directory + "/PNEUMONIA")[random_label_p])))
        plt.title("PNEUMONIA")
        plt.subplot(2,n_of_images // 2, i+2)
        plt.imshow(cv2.imread(os.path.join(directory + "/NORMAL/",os.listdir(directory + "/NORMAL")[random_label_n])))
        plt.title("NORMAL")
        plt.axis("off")
    plt.show()

# %%
view_images(train_dir,16)

# %% [markdown]
# ## Model 1

# %%
# Initialising the CNN
 model = Sequential()
    
 # Step 1 - Convolution
 model.add(Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
 
 # Step 2 - Pooling
 model.add(MaxPooling2D(pool_size = (2,2)))

 # Adding a second convolutional layer        
 model.add(Conv2D(64,(3,3),activation='relu'))
 model.add(MaxPooling2D((2,2)))
          
 model.add(Conv2D(128,(3,3),activation='relu'))
 model.add(MaxPooling2D((2,2)))

 # Step 3 - Flattening
 model.add(Flatten())
      
 # Step 4 - Full connection      
 model.add(Dense(256,activation='relu'))
 model.add(Dense(2,activation='softmax'))
  
 # Compiling the CNN
 model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Part 2 - Fitting the CNN to the images
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('chest_xray/train',
                                                 target_size = (150, 150),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('chest_xray/test',
                                            target_size = (150, 150),
                                            batch_size = 32,
                                            class_mode = 'binary')

history=model.fit_generator(training_set,
                         steps_per_epoch = 1000,
                         epochs = 8,
                         validation_data = test_set,
                         validation_steps = 250,
                         callbacks = [early_stop])
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/8
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7b1cabbf8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7b1cabbf8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.5389WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7b4405268> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7b4405268> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1000/1000 [==============================] - 828s 828ms/step - loss: 0.6969 - accuracy: 0.5389 - val_loss: 0.6931 - val_accuracy: 0.4667
# Epoch 2/8
# 1000/1000 [==============================] - 859s 859ms/step - loss: 0.6932 - accuracy: 0.4999 - val_loss: 0.6931 - val_accuracy: 0.5617
# Epoch 3/8
# 1000/1000 [==============================] - 793s 793ms/step - loss: 0.6932 - accuracy: 0.5042 - val_loss: 0.6931 - val_accuracy: 0.5703
# Epoch 4/8
# 1000/1000 [==============================] - 3205s 3s/step - loss: 0.6932 - accuracy: 0.5011 - val_loss: 0.6931 - val_accuracy: 0.5855

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('val_loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
score  = model.evaluate_generator(test_set, steps=len(test_set), verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 20/20 [==============================] - 7s 340ms/step - loss: 0.6931 - accuracy: 0.5929
# Test loss: 0.693146824836731
# Test accuracy: 0.5929487347602844

# %%
predgen = model.predict_generator(test_set, steps=len(test_set), verbose=1) 
pred = np.argmax(predgen,axis = 1)
y_true=test_set.classes
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7ff7bed4fbf8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7ff7bed4fbf8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 20/20 [==============================] - 8s 379ms/step

# %%
#confution matrix

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_true, pred)
CM
# Out:
# array([[ 73, 161],
#        [115, 275]])

# %%
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()

# %%
tn, fp, fn, tp = CM.ravel()

precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))
# Out:
# Recall of the model is 0.71
# Precision of the model is 0.63

# %% [markdown]
# ## Model 2

# %% [markdown]
# #### Running the first Model 2 with Accuracy optimizer

# %%
# Initialising the CNN
 model_2 = Sequential()

 # Step 1 - Convolution
 model_2.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

 # Step 2 - Pooling
 model_2.add(MaxPooling2D(pool_size = (2, 2)))

 # Adding a second convolutional layer
 model_2.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_2.add(MaxPooling2D(pool_size = (2, 2)))

 model_2.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_2.add(MaxPooling2D(pool_size = (2, 2)))

 # Step 3 - Flattening
 model_2.add(Flatten())

 # Step 4 - Full connection
 model_2.add(Dense(units = 128, activation = 'relu'))
 model_2.add(Dense(units = 1, activation = 'sigmoid'))
    
 print(model.summary())   

 # Compiling the CNN
 model_2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_108 (Conv2D)          (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_92 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_109 (Conv2D)          (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_110 (Conv2D)          (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 36992)             0
# _________________________________________________________________
# dense_90 (Dense)             (None, 256)               9470208
# _________________________________________________________________
# dense_91 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 9,563,970
# Trainable params: 9,563,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('chest_xray/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('chest_xray/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

history=model_2.fit_generator(training_set,
                         steps_per_epoch = 4000,
                         epochs = 10,
                         validation_data = test_set,
                         validation_steps = 1000,
                         callbacks = [early_stop])
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7adac3840> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7adac3840> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9406WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7ae4fb9d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7ae4fb9d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - 1659s 415ms/step - loss: 0.1513 - accuracy: 0.9406 - val_loss: 0.2113 - val_accuracy: 0.9263
# Epoch 2/10
# 4000/4000 [==============================] - 1706s 427ms/step - loss: 0.0857 - accuracy: 0.9675 - val_loss: 0.3603 - val_accuracy: 0.9101
# Epoch 3/10
# 4000/4000 [==============================] - 1744s 436ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.3491 - val_accuracy: 0.9039
# Epoch 4/10
# 4000/4000 [==============================] - 1730s 433ms/step - loss: 0.0498 - accuracy: 0.9814 - val_loss: 0.2953 - val_accuracy: 0.9231
# Epoch 5/10
# 4000/4000 [==============================] - 1727s 432ms/step - loss: 0.0388 - accuracy: 0.9854 - val_loss: 0.3173 - val_accuracy: 0.9199
# Epoch 6/10
# 4000/4000 [==============================] - 1779s 445ms/step - loss: 0.0320 - accuracy: 0.9881 - val_loss: 0.3703 - val_accuracy: 0.8910
# Epoch 7/10
# 4000/4000 [==============================] - 1864s 466ms/step - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.3648 - val_accuracy: 0.9005
# Epoch 8/10
# 4000/4000 [==============================] - 1800s 450ms/step - loss: 0.0245 - accuracy: 0.9907 - val_loss: 0.5364 - val_accuracy: 0.8957
# Epoch 9/10
# 4000/4000 [==============================] - 1669s 417ms/step - loss: 0.0202 - accuracy: 0.9925 - val_loss: 0.4355 - val_accuracy: 0.9105
# Epoch 10/10
# 4000/4000 [==============================] - 1693s 423ms/step - loss: 0.0183 - accuracy: 0.9933 - val_loss: 0.4966 - val_accuracy: 0.8974

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model 2 Loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model 2 Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
plt.figure(figsize=(25,10))
plt.plot(range(0,10),model_2.history.history['accuracy'],color="blue", label="Training accuracy", linestyle="-")
plt.plot(range(0,10),model_2.history.history['val_accuracy'],color="red", label="Validation accuracy", linestyle="-")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Model 2 Training accuracy VS Validation accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.plot(range(0,10),history.history['loss'],color="blue", label="Training loss", linestyle="-")
plt.plot(range(0,10),history.history['val_loss'],color="red", label="Validation loss", linestyle="-")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Model 2 Training loss VS Validation loss")
plt.legend()
plt.show()

# %%
# model_2.evaluate(test_set)

# %%
with tf.device('/device:GPU:0'):
    import datetime
    a = datetime.datetime.now()

    history = model_2.fit_generator(training_set,
                         steps_per_epoch = 4000,
                         epochs = 10,
                         validation_data = test_set,
                         validation_steps = 1000,
                         verbose = 1,
                         callbacks = [early_stop])
    b = datetime.datetime.now()
    print(b-a)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7da5c8ea0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7da5c8ea0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9367WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff8cf543ae8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff8cf543ae8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - 1659s 415ms/step - loss: 0.1606 - accuracy: 0.9367 - val_loss: 0.3539 - val_accuracy: 0.9022
# Epoch 2/10
# 4000/4000 [==============================] - 1746s 437ms/step - loss: 0.1027 - accuracy: 0.9617 - val_loss: 0.3724 - val_accuracy: 0.9038
# Epoch 3/10
# 4000/4000 [==============================] - 1683s 421ms/step - loss: 0.0780 - accuracy: 0.9709 - val_loss: 0.2472 - val_accuracy: 0.9151
# Epoch 4/10
# 4000/4000 [==============================] - 1792s 448ms/step - loss: 0.0614 - accuracy: 0.9771 - val_loss: 0.3401 - val_accuracy: 0.9149
# Epoch 5/10
# 4000/4000 [==============================] - 1756s 439ms/step - loss: 0.0497 - accuracy: 0.9814 - val_loss: 0.3164 - val_accuracy: 0.9183
# Epoch 6/10
# 4000/4000 [==============================] - 1748s 437ms/step - loss: 0.0433 - accuracy: 0.9840 - val_loss: 0.3449 - val_accuracy: 0.9199
# Epoch 7/10
# 4000/4000 [==============================] - 1666s 417ms/step - loss: 0.0357 - accuracy: 0.9867 - val_loss: 0.3088 - val_accuracy: 0.9231
# Epoch 8/10
# 4000/4000 [==============================] - 1642s 410ms/step - loss: 0.0312 - accuracy: 0.9886 - val_loss: 0.3298 - val_accuracy: 0.9185
# Epoch 9/10
# 4000/4000 [==============================] - 1699s 425ms/step - loss: 0.0271 - accuracy: 0.9902 - val_loss: 0.3920 - val_accuracy: 0.9151
# Epoch 10/10
# 4000/4000 [==============================] - 1707s 427ms/step - loss: 0.0254 - accuracy: 0.9906 - val_loss: 0.5688 - val_accuracy: 0.9117
# 4:45:02.028696

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
score  = model_2.evaluate_generator(test_set, steps=len(test_set), verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 20/20 [==============================] - 6s 279ms/step - loss: 0.5130 - accuracy: 0.9167
# Test loss: 0.5130148530006409
# Test accuracy: 0.9166666865348816

# %%
model_2.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
predgen = model_2.predict_generator(test_set, steps=len(test_set), verbose=1) 
pred = np.argmax(predgen,axis = 1)
y_true=test_set.classes
# Out:
# 20/20 [==============================] - 4s 207ms/step

# %%
#confution matrix

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_true, pred)
CM

# %%
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()

# %%
tn, fp, fn, tp = CM.ravel()

precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))

# %% [markdown]
# ## Model 3
#
# ReLU Activation
#
# Dropout

# %%
 # Initialising the CNN
 model_3= Sequential()

 # Step 1 - Convolution
 model_3.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.2))

 # Adding a second convolutional layer
 model_3.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.2))

 # Adding a third convolutional layer
 model_3.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.2))

 # Step 3 - Flattening
 model_3.add(Flatten())

 # Step 4 - Full connection
 model_3.add(Dense(units = 128, activation = 'relu'))
 model_3.add(Dense(units = 1, activation = 'sigmoid'))

 # Compiling the CNN
 model_3.compile(optimizer = optim, loss = 'binary_crossentropy', metrics = ['accuracy'])

 #summary
 model_3.summary()
# Out:
# Model: "sequential_60"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_138 (Conv2D)          (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_122 (MaxPoolin (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_123 (MaxPoolin (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 12, 12, 32)        9248
# _________________________________________________________________
# max_pooling2d_124 (MaxPoolin (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_110 (Dense)            (None, 128)               147584
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 167,105
# Trainable params: 167,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('chest_xray/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('chest_xray/test',
                                            target_size = (64, 64),
                                            batch_size = 64,
                                            class_mode = 'binary')

history=model_3.fit_generator(training_set,
                         steps_per_epoch = 4000,
                         epochs = 5,
                         validation_data = test_set,
                         validation_steps = 1000,
                         callbacks = [early_stop])
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7b00fe9d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7b00fe9d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9248WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7b0380a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7b0380a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4000/4000 [==============================] - 2026s 507ms/step - loss: 0.1905 - accuracy: 0.9248 - val_loss: 0.2950 - val_accuracy: 0.9022
# Epoch 2/5
# 4000/4000 [==============================] - 2131s 533ms/step - loss: 0.1324 - accuracy: 0.9510 - val_loss: 0.2631 - val_accuracy: 0.8942
# Epoch 3/5
# 4000/4000 [==============================] - 2105s 526ms/step - loss: 0.1189 - accuracy: 0.9564 - val_loss: 0.3223 - val_accuracy: 0.8910
# Epoch 4/5
# 4000/4000 [==============================] - 2144s 536ms/step - loss: 0.1088 - accuracy: 0.9608 - val_loss: 0.2762 - val_accuracy: 0.8878
# Epoch 5/5
# 4000/4000 [==============================] - 2032s 508ms/step - loss: 0.1067 - accuracy: 0.9624 - val_loss: 0.2903 - val_accuracy: 0.9166

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('val_loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
score  = model_3.evaluate_generator(test_set, steps=len(test_set), verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
predgen = model_3.predict_generator(test_set, steps=len(test_set), verbose=1) 
pred = np.argmax(predgen,axis = 1)
y_true=test_set.classes

# %%
#confution matrix

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_true, pred)
CM

# %%
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()

# %%
tn, fp, fn, tp = CM.ravel()

precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))

# %%
 # Initialising the CNN
 model_3= Sequential()

 # Step 1 - Convolution
 model_3.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.3))

 # Adding a second convolutional layer
 model_3.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.3))

 # Adding a third convolutional layer
 model_3.add(Conv2D(32, (3, 3), activation = 'relu'))
 model_3.add(MaxPooling2D(pool_size = (2, 2)))
 model_3.add(Dropout(0.3))

 # Step 3 - Flattening
 model_3.add(Flatten())

 # Step 4 - Full connection
 model_3.add(Dense(units = 128, activation = 'relu'))
 model_3.add(Dense(units = 1, activation = 'sigmoid'))

 # Compiling the CNN
 model_3.compile(optimizer = optim, loss = 'binary_crossentropy', metrics = ['accuracy'])

 #summary
 model_3.summary()
# Out:
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_144 (Conv2D)          (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_128 (MaxPoolin (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_129 (MaxPoolin (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 12, 12, 32)        9248
# _________________________________________________________________
# max_pooling2d_130 (MaxPoolin (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_50 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_114 (Dense)            (None, 128)               147584
# _________________________________________________________________
# dense_115 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 167,105
# Trainable params: 167,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('chest_xray/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('chest_xray/test',
                                            target_size = (64, 64),
                                            batch_size = 64,
                                            class_mode = 'binary')

history=model_3.fit_generator(training_set,
                         steps_per_epoch = 100,
                         epochs = 100,
                         validation_data = test_set,
                         validation_steps = 50,
                         callbacks = [early_stop])
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7c1c31378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff7c1c31378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - ETA: 0s - loss: 0.5742 - accuracy: 0.7469WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7c26d18c8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7ff7c26d18c8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - 77s 775ms/step - loss: 0.5742 - accuracy: 0.7469 - val_loss: 0.5796 - val_accuracy: 0.7901
# Epoch 2/100
# 100/100 [==============================] - 80s 801ms/step - loss: 0.4226 - accuracy: 0.8119 - val_loss: 0.4646 - val_accuracy: 0.8420
# Epoch 3/100
# 100/100 [==============================] - 70s 696ms/step - loss: 0.3307 - accuracy: 0.8612 - val_loss: 0.4287 - val_accuracy: 0.8317
# Epoch 4/100
# 100/100 [==============================] - 63s 625ms/step - loss: 0.3191 - accuracy: 0.8697 - val_loss: 0.3964 - val_accuracy: 0.8721
# Epoch 5/100
# 100/100 [==============================] - 64s 643ms/step - loss: 0.2918 - accuracy: 0.8753 - val_loss: 0.3864 - val_accuracy: 0.8279
# Epoch 6/100
# 100/100 [==============================] - 59s 588ms/step - loss: 0.2783 - accuracy: 0.8856 - val_loss: 0.3707 - val_accuracy: 0.8824
# Epoch 7/100
# 100/100 [==============================] - 60s 597ms/step - loss: 0.2593 - accuracy: 0.8916 - val_loss: 0.3394 - val_accuracy: 0.8907
# Epoch 8/100
# 100/100 [==============================] - 61s 607ms/step - loss: 0.2427 - accuracy: 0.9019 - val_loss: 0.3312 - val_accuracy: 0.8788
# Epoch 9/100
# 100/100 [==============================] - 60s 605ms/step - loss: 0.2304 - accuracy: 0.9047 - val_loss: 0.3042 - val_accuracy: 0.8875
# Epoch 10/100
# 100/100 [==============================] - 60s 598ms/step - loss: 0.2145 - accuracy: 0.9191 - val_loss: 0.3250 - val_accuracy: 0.8814
# Epoch 11/100
# 100/100 [==============================] - 60s 602ms/step - loss: 0.2186 - accuracy: 0.9150 - val_loss: 0.2943 - val_accuracy: 0.8846
# Epoch 12/100
# 100/100 [==============================] - 60s 598ms/step - loss: 0.2145 - accuracy: 0.9131 - val_loss: 0.2618 - val_accuracy: 0.8942

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('val_loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
score  = model_3.evaluate_generator(test_set, steps=len(test_set), verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 [==============================] - 5s 501ms/step - loss: 0.2727 - accuracy: 0.8926
# Test loss: 0.2726827561855316
# Test accuracy: 0.8926281929016113

# %%
predgen = model_3.predict_generator(test_set, steps=len(test_set), verbose=1) 
pred = np.argmax(predgen,axis = 1)
y_true=test_set.classes
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7ff7c902b378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7ff7c902b378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 10/10 [==============================] - 5s 491ms/step

# %%
#confution matrix

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_true, pred)
CM
# Out:
# array([[234,   0],
#        [390,   0]])

# %%
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()

# %%
tn, fp, fn, tp = CM.ravel()

precision = tp/(tp+fp)
recall = tp/(tp+fn)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))
